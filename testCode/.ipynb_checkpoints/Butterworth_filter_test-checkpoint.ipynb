# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import random
from scipy import signal

# %%
body_acc_x = pd.read_csv('../testData/body_acc_x_test.txt', delim_whitespace=True, header=None).to_numpy()
y = pd.read_csv('../testData/y_test.txt', delim_whitespace=True, header=None).to_numpy()

# %%
def showplot(data, after):
    plt.plot(data)
    plt.plot(after)
    plt.show()
def filter(cutoff_freq, sensor_freq, analog, data):
    b, a = signal.butter(3, 2*cutoff_freq/sensor_freq, btype='lowpass', analog=analog, output='ba')
    filtedData = signal.filtfilt(b, a, data)
    return filtedData

# %%
index = random.randint(0,2947)
data = body_acc_x[index]
print('index: ',index, '\ty: ', y[index][0], '\n')

for int in np.linspace(0.1,1,10):
    print('cutoff_freq: ',int)
    after = filter(int, 50, False, body_acc_x)[index]
    showplot(data, after)
#     print('diff: \n', after-data)
    print('diff. mean: ', np.mean(after-data))
    print('diff. std: ', np.std(after-data), '\n')
for int in range(1, 25, 1):
    print('cutoff_freq: ',int)
    after = filter(int, 50, False, body_acc_x)[index]
    showplot(data, after)
#     print('diff: \n', after-data)
    print('diff. mean: ', np.mean(after-data))
    print('diff. std: ', np.std(after-data), '\n')
# Out:
# index:  978 	y:  6
#
# cutoff_freq:  0.1
# diff. mean:  0.002707548033143318
# diff. std:  0.002277332621025554
#
# cutoff_freq:  0.2
# diff. mean:  0.0005351588972082011
# diff. std:  0.002290778273831063
#
# cutoff_freq:  0.30000000000000004
# diff. mean:  5.897631540877238e-05
# diff. std:  0.002291554545735843
#
# cutoff_freq:  0.4
# diff. mean:  4.573220617244045e-05
# diff. std:  0.0022625880585714214
#
# cutoff_freq:  0.5
# diff. mean:  3.924904919591581e-05
# diff. std:  0.002252633698591218
#
# cutoff_freq:  0.6
# diff. mean:  2.442113783258168e-05
# diff. std:  0.0022454919812615287
#
# cutoff_freq:  0.7000000000000001
# diff. mean:  1.6613943097852822e-05
# diff. std:  0.0022416870268856617
#
# cutoff_freq:  0.8
# diff. mean:  1.3791059121721439e-05
# diff. std:  0.0022412095840886746
#
# cutoff_freq:  0.9
# diff. mean:  1.267385804764149e-05
# diff. std:  0.0022417682241883084
#
# cutoff_freq:  1.0
# diff. mean:  1.2321874782218417e-05
# diff. std:  0.00224164057443981
#
# cutoff_freq:  1
# diff. mean:  1.2321874782218417e-05
# diff. std:  0.00224164057443981
#
# cutoff_freq:  2
# diff. mean:  2.0103708927407372e-05
# diff. std:  0.002087010634933964
#
# cutoff_freq:  3
# diff. mean:  2.0310258709285582e-05
# diff. std:  0.0017904193323236318
#
# cutoff_freq:  4
# diff. mean:  1.9514576293642035e-05
# diff. std:  0.0016148702602122238
#
# cutoff_freq:  5
# diff. mean:  1.318326602069523e-05
# diff. std:  0.001454229622715254
#
# cutoff_freq:  6
# diff. mean:  7.180978890972379e-06
# diff. std:  0.0012831468402455855
#
# cutoff_freq:  7
# diff. mean:  3.047990705273169e-06
# diff. std:  0.0011247812196142851
#
# cutoff_freq:  8
# diff. mean:  -6.26661085940036e-08
# diff. std:  0.0010014323215434117
#
# cutoff_freq:  9
# diff. mean:  -2.6783889635302015e-06
# diff. std:  0.0008990946960548214
#
# cutoff_freq:  10
# diff. mean:  -4.6264583787932956e-06
# diff. std:  0.0008015471321195172
#
# cutoff_freq:  11
# diff. mean:  -5.466583658236804e-06
# diff. std:  0.0007050731829355874
#
# cutoff_freq:  12
# diff. mean:  -5.083615647496736e-06
# diff. std:  0.0006134400155452242
#
# cutoff_freq:  13
# diff. mean:  -3.870214128021463e-06
# diff. std:  0.0005326905805393972
#
# cutoff_freq:  14
# diff. mean:  -2.470237624854135e-06
# diff. std:  0.00046519768815738853
#
# cutoff_freq:  15
# diff. mean:  -1.4045824812293794e-06
# diff. std:  0.00040645070721982853
#
# cutoff_freq:  16
# diff. mean:  -8.613217987781618e-07
# diff. std:  0.00034904469448477884
#
# cutoff_freq:  17
# diff. mean:  -6.939621303069183e-07
# diff. std:  0.00028973662721114686
#
# cutoff_freq:  18
# diff. mean:  -6.038958704992894e-07
# diff. std:  0.00022900921539432397
#
# cutoff_freq:  19
# diff. mean:  -4.2836617387770317e-07
# diff. std:  0.00016305571963510758
#
# cutoff_freq:  20
# diff. mean:  -2.383909048887046e-07
# diff. std:  9.150917739298348e-05
#
# cutoff_freq:  21
# diff. mean:  -1.0873185491868913e-07
# diff. std:  3.59850140123405e-05
#
# cutoff_freq:  22
# diff. mean:  -1.567299729715255e-08
# diff. std:  1.0918948528268463e-05
#
# cutoff_freq:  23
# diff. mean:  -2.7278518095464095e-08
# diff. std:  3.3912253377783192e-06
#
# cutoff_freq:  24
# diff. mean:  -8.058614112913021e-09
# diff. std:  3.076278290055824e-06
